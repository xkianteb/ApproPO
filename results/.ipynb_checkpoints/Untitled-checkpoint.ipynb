# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob

# %%
data = pd.read_csv(files[0])
# plt.figure(figsize=(20,10))
# ax = plt.gca()
# # ax2 = ax.twinx()

# ax.plot(data.ep, data.dist_uni, marker='o', label='dist_uni')
# ax.plot(data.ep, data.reward, marker='o', label='reward')
# ax.plot(data.ep, data.reward, marker='o', label='prob_failure')
# ax.set_ylabel('Objective', fontsize=14)
# ax.set_xlabel('epoch', fontsize=14)

# # ax2.plot([i for i in range(len(obj))], [val for val in exec_time], linestyle='dashed', color='orange', label='exec_time')
# # ax2.set_ylabel('Execution time')
# # ax2.set_ylim(0, max(exec_time))

# ax.legend()
# # ax2.legend(loc='lower right')
# plt.show();

# %%
a = np.arange(3000)
df = pd.DataFrame(a, columns=['ep'])
df
# Out:
#         ep
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
# ...    ...
# 2995  2995
# 2996  2996
# 2997  2997
# 2998  2998
# 2999  2999
#
# [3000 rows x 1 columns]

# %%
d = data.merge(df, how = 'outer', on='ep').sort_values(by='ep').fillna(method='ffill')
f=['f' for i in range(3000)]
d['case'] = f
d
# Out:
#         ep  traj    reward  prob_failure  \
# 0        0  25.0 -0.254000          -1.0
# 1        1  25.0 -0.217000          -1.0
# 2        2  25.0 -0.204667          -1.0
# 3        3  25.0 -0.198500          -1.0
# 4        4  25.0 -0.198500          -1.0
# ...    ...   ...       ...           ...
# 2995  2995  25.0 -0.198500          -1.0
# 2996  2996  25.0 -0.198500          -1.0
# 2997  2997  25.0 -0.198500          -1.0
# 2998  2998  25.0 -0.198500          -1.0
# 2999  2999  25.0 -0.198500          -1.0
#
#                                                     obs  dist_uni  entropy  \
# 0     {'obs': [0.0598343685300207, 0.025523809523809...  0.269230      0.0
# 1     {'obs': [0.06876522348069662, 0.07558870214752...  0.223010      0.0
# 2     {'obs': [0.07174217513092192, 0.09227699968876...  0.217991      0.0
# 3     {'obs': [0.07323065095603458, 0.10062114845938...  0.217763      0.0
# 4     {'obs': [0.07323065095603458, 0.10062114845938...  0.217763      0.0
# ...

# %%
len('D:/Anhs/SMU/AI/Computation and Optimization/paper/ApproPO/results\\')
# Out:
# 66

# %%
import glob
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path  
# All files and directories ending with .txt and that don't begin with a dot:
root_dir="D:/Anhs/SMU/AI/Computation and Optimization/paper/ApproPO/results/"
files = glob.glob(f"{root_dir}prob_failure_*.csv")
files= [a[66:] for a in files]
files
prob_failures=['prob_failure_0_diversity_0.12.csv','prob_failure_-0.1_diversity_0.12.csv', 'prob_failure_-0.2_diversity_0.12.csv','prob_failure_-0.3_diversity_0.12.csv']
thresholds = ['prob_failure_-0.2_diversity_0.06.csv',
 'prob_failure_-0.2_diversity_0.12.csv',
 'prob_failure_-0.2_diversity_0.3.csv',
 'prob_failure_-0.2_diversity_0.csv']

# %%
datas = []
for f in files:
    data = pd.read_csv(f)
    data = data.merge(df, how = 'outer', on='ep').sort_values(by='ep').fillna(method='ffill')
    cases=[f for i in range(3000)]
    d['case'] = cases
    datas.append(data)
    plt.figure(figsize=(20,10))
    ax = plt.gca()
    # ax2 = ax.twinx()
    # x= np.range
    ax.plot(data.ep, data.dist_uni, marker='o', label='dist_uni')
    ax.plot(data.ep, data.reward, marker='o', label='reward')
    ax.plot(data.ep, data.prob_failure, marker='o', label='prob_failure')
    ax.set_ylabel('Objective', fontsize=14)
    ax.set_xlabel('epoch', fontsize=14)
    ax.set_title(f)
    ax.legend()
#     filename= Path(f).stem
#     plt.savefig(f'{root_dir}imgs/{filename}.png')
    
    plt.show();

# %%
datas = []
for f in files:
    data = pd.read_csv(f)
    data = data.merge(df, how = 'outer', on='ep').sort_values(by='ep').fillna(method='ffill')
    cases=[f for i in range(3000)]
    data['case'] = cases
    datas.append(data)
datas = pd.concat(datas)
datas
# Out:
#         ep  traj    reward  prob_failure  \
# 0        0  25.0 -0.854000          -1.0
# 1        1  25.0 -0.676000          -1.0
# 2        2  25.0 -0.616667          -1.0
# 3        3  25.0 -0.587000          -1.0
# 2973     4  25.0 -0.587000          -1.0
# ...    ...   ...       ...           ...
# 2995  2995  25.0 -0.198500          -1.0
# 2996  2996  25.0 -0.198500          -1.0
# 2997  2997  25.0 -0.198500          -1.0
# 2998  2998  25.0 -0.198500          -1.0
# 2999  2999  25.0 -0.198500          -1.0
#
#                                                     obs  dist_uni  entropy  \
# 0     {'obs': [0.1634732257138896, 0.114148829501526...  0.289161      0.0
# 1     {'obs': [0.1562270773474093, 0.100571548247896...  0.264045      0.0
# 2     {'obs': [0.1538116945585825, 0.096045787830020...  0.259287      0.0
# 3     {'obs': [0.1526040031641691, 0.093782907621081...  0.257655      0.0
# 2973  {'obs': [0.1526040031641691, 0.093782907621081...  0.257655      0.0
# ...

# %%
plt.figure(figsize=(30,10))
ax = plt.gca()
for c in datas.case.unique():
    d = datas.loc[datas['case']==c].sort_values(by=['ep'])
#     print(len(d))
    ax.plot(d.ep, d.dist_uni, label=c)
ax.set_xlabel('epoch', fontsize=14)
title = 'Distance from uniform by cases'
ax.set_title('Distance from uniform by cases')
ax.legend()
    filename= Path(f).stem
    plt.savefig(f'{root_dir}imgs/{filename}.png')

plt.show();

# %%
plot_cases =[('dist_uni', 'Distance from uniform by cases'), ('reward', 'Reward by cases'), ('prob_failure', 'Proablility of failure by cases')]

# %%
for p in plot_cases:
    if p[0] == 'prob_failure':
        plt.figure(figsize=(30,10))
        ax = plt.gca()
        for c in datas.case.unique():

            if c in thresholds:
                d = datas.loc[datas['case']==c].sort_values(by=['ep'])
            #     print(len(d))
                ax.plot(d.ep, d[p[0]], label=c)
        ax.set_xlabel('epoch', fontsize=14)
        title = p[1]+'by_thresholds'
        ax.set_title(title)
        ax.legend()
    #         filename= Path(f).stem
        plt.savefig(f'{root_dir}imgs/{p[1]}_by_thresholds.png')

        plt.show()

# %%
for p in plot_cases:
#     if p[0] == 'prob_failure':
    plt.figure(figsize=(30,10))
    ax = plt.gca()
    for c in datas.case.unique():
        if c in thresholds:
            d = datas.loc[datas['case']==c].sort_values(by=['ep'])
        #     print(len(d))
            ax.plot(d.ep, d[p[0]], label=c)
    ax.set_xlabel('epoch', fontsize=14)
    title = p[1]+' by thresholds'
    ax.set_title(title)
    ax.legend()
#         filename= Path(f).stem
    plt.savefig(f'{root_dir}imgs/{p[1]}_by_thresholds.png')

    plt.show()

# %%
for p in plot_cases:
#     if p[0] == 'prob_failure':
    plt.figure(figsize=(30,10))
    ax = plt.gca()
    for c in datas.case.unique():
        if c in prob_failures:
            d = datas.loc[datas['case']==c].sort_values(by=['ep'])
        #     print(len(d))
            ax.plot(d.ep, d[p[0]], label=c)
    ax.set_xlabel('epoch', fontsize=14)
    title = p[1]+'by changing prob of failure'
    ax.set_title(title)
    ax.legend()
#         filename= Path(f).stem
    plt.savefig(f'{root_dir}imgs/{p[1]} by changing prob of failure.png')

    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [59], in <cell line: 1>()
#       4 ax = plt.gca()
#       5 for c in datas.case.unique():
# ----> 6     if c in prob:
#       7         d = datas.loc[datas['case']==c].sort_values(by=['ep'])
#       8     #     print(len(d))
#
# NameError: name 'prob' is not defined
